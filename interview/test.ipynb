# %%
#1

import csv
fp=open(r'D:\Cloud Computing and Python\Python\22042023\accounts.csv','r')
fr=csv.reader(fp)
def aall():
    z=[]
    for i in fr:
        z+=[i]
    return z
v=aall()




def account_numbers():    
    fp=open(r'D:\Cloud Computing and Python\Python\22042023\accounts.csv','r')
    fr=csv.reader(fp)
    ad=[]
    for i in fr:
        ad+=[i[1]]
    return ad



fp=open(r'D:\Cloud Computing and Python\Python\22042023\accounts.csv','a',newline='')   # add account
fr=csv.writer(fp)
def reg_account(anumber):
    ra=[]
    if str(anumber) in account_numbers():
        print('account already exist')
    else:
        name=input('enter name:')
        ra.append(name)
        account=str(anumber)
        ra.append(account)
        bank=input('enter bank name:')
        ra.append(bank)
        status='Active'
        ra.append(status)
        balance=input('enter balance:')
        ra.append(balance)
        created_at=input('enter created_at date:')
        ra.append(created_at)
        updated_at=input('enter updated_at date')
        ra.append(updated_at)
        
        fr.writerow(ra)
        

fp=open('a.csv','a',newline='')     #remove account
fr=csv.writer(fp)
def remove_account(anumber):
    for i in range(0,len(v)):
        if v[i][1]==str(anumber):
            v[i][3]='closed'
            fr.writerows(v)
            


def balance(anumber):            #balance
    for i in range(0,len(v)):
        if v[i][1]==str(anumber):
            return v[i][4]
        

        

fp=open(r'D:\Cloud Computing and Python\Python\22042023\transactions.csv','a')     #withdraw
fr=csv.writer(fp)
def withdraw(Date, account_no, amount):
    l=[]
    id=input('enter id:')
    l.append(id)
    l.append(Date)
    reference_id=input('enter reference id:')
    l.append(reference_id)
    l.append(account_no)
    type='withdraw'
    l.append(type)
    mode='debit'
    l.append(mode)
    l.append(amount)
    l.append(int(balance(account_no))-int((amount)))
    fr.writerow(l)

fp=open(r'D:\Cloud Computing and Python\Python\22042023\transactions.csv','a')           #deposit
fr=csv.writer(fp)
def deposit(Date, account_no, amount):
    l=[]
    id=input('enter id:')
    l.append(id)
    l.append(Date)
    reference_id=input('enter reference id:')
    l.append(reference_id)
    l.append(account_no)
    type='deposit'
    l.append(type)
    mode='credit'
    l.append(mode)
    l.append(amount)
    l.append(int(balance(account_no))+int((amount)))
    fr.writerow(l)

fp=open(r'D:\Cloud Computing and Python\Python\22042023\t.csv','a')           #transfer
fr=csv.writer(fp)
def transfer(Date, from_account_no, to_account_no, amount):
    withdraw(Date, from_account_no, amount)
    deposit(Date, to_account_no, amount)

# %%
#2

import csv
fp=open(r'D:\Cloud Computing and Python\Python\22042023\2question.csv','r')
fr=csv.reader(fp)
z=[]
for i in fr:
    z+=[i]
print(z)

print('-'*60)

l=['Timestamp', 'metric1', 'metric2', 'metric3', 'metric4','metric5']
fp=open(r'D:\Cloud Computing and Python\Python\22042023\2answer.csv','w')
fr=csv.writer(fp)
fr.writerow(l)

fp=open(r'D:\Cloud Computing and Python\Python\22042023\2answer.csv','a',newline='')
fr=csv.writer(fp)
for i in range(1,4):
    fr.writerow(z[i])
fp.close()

fp=open(r'D:\Cloud Computing and Python\Python\22042023\2answer.csv','a',newline='')
fr=csv.writer(fp)
for i in range(5,8):
    fr.writerow(z[i])
fp.close()
# Out:
# [['Timestamp', ' metric1', ' metric2', ' metric3', ' metric4'], ['12345', ' 1', ' 2', ' 3', ' "Yes"'], ['12346', ' 1', ' 2', ' 3', ' "No"'], ['12347', ' 1', ' 2', ' 3', ' "Yes"'], ['Timestamp', ' metric1', ' metric4', ' metric3'], ['12348', ' 1', ' "Yes"', ' 2'], ['12349', ' 1', '  "No"', ' 3'], ['12350', ' 1', ' "Yes"', ' 4'], ['Timestamp', ' metric1', ' metric2', ' metric3', ' metric5'], ['12351', ' 1', ' 2', ' 3', ' 4'], ['12352', ' 1', ' 2', ' 3', ' 4'], ['12353', ' 1', ' 2', ' 3', ' 4']]
# ------------------------------------------------------------

# %%
import csv
fp=open(r'D:\Cloud Computing and Python\Python\22042023\transactions.csv','r')
fr=csv.reader(fp)
def all():
    z=[]
    for i in fr:
        z+=[i]
    return z
w=all()

for i in range(0,len(w)):
    print(w[i])

print('-'*50)

fp=open(r'D:\Cloud Computing and Python\Python\22042023\t.csv','a')
fr=csv.writer(fp)
def withdraw(Date, account_no, amount):
    l=[]
    id='5'
    l.append(id)
    l.append(Date)
    reference_id='129'
    l.append(reference_id)
    l.append(account_no)
    type='withdraw'
    l.append(type)
    mode='debit'
    l.append(mode)
    l.append(amount)
    l.append(int(balance(account_no))-int(amount))
    fr.writerow(l)
withdraw('22/04/2022','123457','5000')
    



fp=open(r'D:\Cloud Computing and Python\Python\22042023\t.csv','a')    
fr=csv.writer(fp)
def deposit(Date, account_no, amount):
    l=[]
    id='55'
    l.append(id)
    l.append(Date)
    reference_id='129'
    l.append(reference_id)
    l.append(account_no)
    type='deposit'
    l.append(type)
    mode='credit'
    l.append(mode)
    l.append(amount)
    l.append(int(balance(account_no))+int(amount))
    fr.writerow(l)
# Out:
# ['Id', ' date', ' reference_id', '  account', ' type', ' mode', ' amount', ' balance']
# ['1', ' 20/04/2023', '123', ' 12345', ' transfer', ' credit', ' 500', ' 1000']
# ['2', ' 20/04/2023', '123', ' 12346', ' transfer', ' debit', ' 500', ' 1000']
# ['3', ' 20/04/2023', '124', ' 12345', ' withdraw', ' debit', ' 500', ' 1000']
# ['4', ' 20/04/2023', '125', ' 12345', ' deposit', ' credit', ' 500', ' 1000']
# --------------------------------------------------

# %%
import csv
fp=open(r'D:\Cloud Computing and Python\Python\22042023\t.csv','w',newline='')
fr=csv.writer(fp)
li=[20,30,40,50,500]
fr.writerow(li)
# Out:
# 17

# %%
import csv
fp=open(r'D:\Cloud Computing and Python\Python\interview\2question.csv','r')
fr=csv.DictReader(fp)
for i in fr:
    print(i)
# Out:
# {'Timestamp': '12345', ' metric1': ' 1', ' metric2': ' 2', ' metric3': ' 3', ' metric4': ' "Yes"'}
# {'Timestamp': '12346', ' metric1': ' 1', ' metric2': ' 2', ' metric3': ' 3', ' metric4': ' "No"'}
# {'Timestamp': '12347', ' metric1': ' 1', ' metric2': ' 2', ' metric3': ' 3', ' metric4': ' "Yes"'}
# {'Timestamp': 'Timestamp', ' metric1': ' metric1', ' metric2': ' metric4', ' metric3': ' metric3', ' metric4': None}
# {'Timestamp': '12348', ' metric1': ' 1', ' metric2': ' "Yes"', ' metric3': ' 2', ' metric4': None}
# {'Timestamp': '12349', ' metric1': ' 1', ' metric2': '  "No"', ' metric3': ' 3', ' metric4': None}
# {'Timestamp': '12350', ' metric1': ' 1', ' metric2': ' "Yes"', ' metric3': ' 4', ' metric4': None}
# {'Timestamp': 'Timestamp', ' metric1': ' metric1', ' metric2': ' metric2', ' metric3': ' metric3', ' metric4': ' metric5'}
# {'Timestamp': '12351', ' metric1': ' 1', ' metric2': ' 2', ' metric3': ' 3', ' metric4': ' 4'}
# ...

# %%
import csv

fp=open(r"D:\Cloud Computing and Python\Python\interview\a.csv",'a',newline='')
fr=csv.DictWriter(fp,['name','account','bank','status','balance','created_at','updated_at'])
fr.writeheader()
fp.close()

# %%
class a:

    def __init__(self):
        self.name=input()
        self.age=int(input())

obj=a()

def header():
    import csv
    fp=open(r'D:\Cloud Computing and Python\Python\interview\a.csv','w')
    fr=csv.DictWriter(fp,['name','age'])
    fr.writeheader()
    fp.close()
# header()

l=['name','age']
def details():
    fp=open(r'D:\Cloud Computing and Python\Python\interview\a.csv','a',newline='')
    fr=csv.DictWriter(fp,l)
    fr.writerow({'name':obj.name,'age':obj.age})
details()
