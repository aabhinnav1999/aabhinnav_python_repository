# %%
#1

from captcha.image import ImageCaptcha
import random

image=ImageCaptcha(height=200,width=500)

def generate_captcha_text():
    characters='abcdefghijklmnopqrstuvwxyz0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    # text=''.join(random.choice(characters) for _ in range(6))
    text=''
    for i in range(6):
        text+=random.choice(characters)
    return text

captcha_text=generate_captcha_text()

data=image.generate(captcha_text)

image.write(captcha_text,'capimg1.jpeg')

from PIL import Image
Image.open('capimg1.jpeg')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x200>

# %%
ans=input("enter output:")

if captcha_text==ans:
    print(True)
else:
    print(ans)
    print(False,captcha_text)

# print(captcha_text)
# Out:
# True
