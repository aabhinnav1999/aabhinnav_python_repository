# %%
#1 equity_history

from nsepython import *
from datetime import date

res=equity_history(symbol='tcs',series='EQ',start_date="01-04-2024",end_date="22-04-2024")

print('\n',type(res))
print('\n',res)
# Out:
# {'data': [{'_id': '66266b2c8b80d02869c4ba0e', 'CH_SYMBOL': 'TCS', 'CH_SERIES': 'EQ', 'CH_MARKET_TYPE': 'N', 'CH_TRADE_HIGH_PRICE': 3878, 'CH_TRADE_LOW_PRICE': 3812, 'CH_OPENING_PRICE': 3837, 'CH_CLOSING_PRICE': 3864.6, 'CH_LAST_TRADED_PRICE': 3875.9, 'CH_PREVIOUS_CLS_PRICE': 3826.2, 'CH_TOT_TRADED_QTY': 1728883, 'CH_TOT_TRADED_VAL': 6641643736.05, 'CH_52WEEK_HIGH_PRICE': 4254.75, 'CH_52WEEK_LOW_PRICE': 3126.15, 'CH_TOTAL_TRADES': 99078, 'CH_ISIN': 'INE467B01029', 'CH_TIMESTAMP': '2024-04-22', 'TIMESTAMP': '2024-04-21T18:30:00.000Z', 'createdAt': '2024-04-22T13:50:36.142Z', 'updatedAt': '2024-04-22T13:50:36.142Z', '__v': 0, 'SLBMH_TOT_VAL': None, 'VWAP': 3841.58, 'mTIMESTAMP': '22-Apr-2024'}, {'_id': '66225d00337be0542c00a3ca', 'CH_SYMBOL': 'TCS', 'CH_SERIES': 'EQ', 'CH_MARKET_TYPE': 'N', 'CH_TIMESTAMP': '2024-04-19', 'TIMESTAMP': '2024-04-18T18:30:00.000Z', 'CH_TRADE_HIGH_PRICE': 3852.55, 'CH_TRADE_LOW_PRICE': 3800.9, 'CH_OPENING_PRICE': 3838, 'CH_CLOSING_PRICE': 3826.2, 'CH_LAST_TRA
# ...

# %%
#2

res=nsefetch('https://www.nseindia.com/api/equity-stockIndices?index=SECURITIES%20IN%20F%26O')

for i in res:
    print(i,' : ',res[i])
# Out:
# {'name': 'SECURITIES IN F&O', 'advance': {'advances': 121, 'declines': 60, 'unchanged': 1}, 'timestamp': '23-Apr-2024 13:58:50', 'data': [{'symbol': 'IDEA', 'identifier': '', 'series': 'EQ', 'open': '13', 'dayHigh': '14.75', 'dayLow': '12.95', 'lastPrice': '14.35', 'previousClose': '12.9', 'change': 1.45, 'pChange': 11.24, 'totalTradedVolume': 2147483647, 'totalTradedValue': 33200097182.62, 'lastUpdateTime': '31-DEC-2999', 'yearHigh': '18.4', 'yearLow': '6.25', 'nearWKH': 22.010869565217387, 'nearWKL': -129.6, 'perChange365d': 100, 'date365dAgo': '21-Apr-2023', 'chart365dPath': 'https://nsearchives.nseindia.com/365d/IDEA-EQ.svg', 'date30dAgo': '22-Mar-2024', 'perChange30d': -3.01, 'chart30dPath': 'https://nsearchives.nseindia.com/30d/IDEA-EQ.svg', 'chartTodayPath': 'https://nsearchives.nseindia.com/today/IDEAEQN.svg', 'meta': {'symbol': 'IDEA', 'companyName': 'Vodafone Idea Limited', 'industry': 'TELECOMMUNICATION - SERVICES', 'activeSeries': ['EQ'], 'debtSeries': [], 'isFNOSec': Tru
# ...

# %%
from nsepython import *

end_date = datetime.datetime.now().strftime("%d-%m-%Y")
end_date = str(end_date)

start_date = (datetime.datetime.now()- datetime.timedelta(days=40)).strftime("%d-%m-%Y")
start_date = str(start_date)

symbol = "SBIN"
series = "EQ"

df = equity_history(symbol,series,start_date,end_date)

print(df)
# Out:
#                          _id CH_SYMBOL CH_SERIES CH_MARKET_TYPE  \
# 0   65f2e6ff8643f48501bb3dc1      SBIN        EQ              N
# 1   65f4387fefaa46581de62a6e      SBIN        EQ              N
# 2   65f82cff14748b2422170a07      SBIN        EQ              N
# 3   65f97e7f9d54172e54339a38      SBIN        EQ              N
# 4   65facfffcf5221fc299a3e41      SBIN        EQ              N
# 5   65fc217f6db2d5c9a6b5cc48      SBIN        EQ              N
# 6   65fd72ffeaeb514865379c2c      SBIN        EQ              N
# 7   6602db37d9e78bbf11401344      SBIN        EQ              N
# 8   66040cd79f25a30f219d3683      SBIN        EQ              N
# 9   66055bffefb4b6a6c1a50bb3      SBIN        EQ              N
# 10  660aa1ff41fa55a2bf7d8ee1      SBIN        EQ              N
# 11  660bf380f7e1ee6c9dc35a6a      SBIN        EQ              N
# 12  660d4500e93745abdbf5263b      SBIN        EQ              N
# 13  660e96805b7d313102eb06d4      SBIN        EQ              N
# ...
