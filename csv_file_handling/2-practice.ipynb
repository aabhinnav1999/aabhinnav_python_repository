# %%
#1

import csv

fp=open(r"D:\Python\csv_file_handling\2-practice.csv",'r')

fr=csv.reader(fp)

for i in fr:
    if i[1].endswith(".")==True and float(i[-1])>200000:
        print(i)
# Out:
# ['1', 'Tech Innovations Inc.', '523456.78', '312345.67', '211111.11']
# ['6', 'Aerospace Dynamics Corp.', '1234567.89', '987654.32', '246913.57']
# ['22', 'Machinery Manufacturing Corp.', '1456789.01', '1234567.89', '222221.12']
# ['24', 'Retail Innovations Group Inc.', '7654321.00', '6543210.00', '1111111']

# %%
#2

import csv

fp=open(r"D:\Python\csv_file_handling\2-practice.csv",'r')

fr=csv.DictReader(fp)

for i in fr:
    print(i)
# Out:
# {'ID': '1', 'Company Name': 'Tech Innovations Inc.', 'Revenue': '523456.78', 'Expenditure': '312345.67', 'Profit': '211111.11'}
# {'ID': '2', 'Company Name': 'Green Energy Solutions', 'Revenue': '754321.45', 'Expenditure': '612345.89', 'Profit': '141975.56'}
# {'ID': '3', 'Company Name': 'HealthCare Plus', 'Revenue': '612345.12', 'Expenditure': '459876.54', 'Profit': '152468.58'}
# {'ID': '4', 'Company Name': 'Retail World Ltd.', 'Revenue': '834567.89', 'Expenditure': '721234.56', 'Profit': '113333.33'}
# {'ID': '5', 'Company Name': 'Finance Gurus LLC', 'Revenue': '912345.67', 'Expenditure': '859876.54', 'Profit': '52469.13'}
# {'ID': '6', 'Company Name': 'Aerospace Dynamics Corp.', 'Revenue': '1234567.89', 'Expenditure': '987654.32', 'Profit': '246913.57'}
# {'ID': '7', 'Company Name': 'Cyber Security Experts', 'Revenue': '789012.34', 'Expenditure': '423456.78', 'Profit': '365555.56'}
# ...
