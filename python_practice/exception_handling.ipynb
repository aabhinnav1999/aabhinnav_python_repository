# %%
#1  specific exception

# a=19
# c=a+z
# print(c)

try:
    a=19
    c=a+z
except NameError:
    pass
finally:
    print(c)
# Out:
# 19

# %%
#2   generic exception

print('start')

class sample:
    x=10
obj=sample()

try:
    print(sample.y)
except Exception:
    print('check your program')
    sample.y=int(input('enter the value for sample.y'))
    print('program modified')
finally:
    print("sample.y is",sample.y)
    print('the end')
# Out:
# start
# check your program
# program modified
# sample.y is 19
# the end

# %%
#3  default exception

try:
    for i in range(1,100000):
        print(i)
except:
    print('thank you')

# %%
# custom exception (using raise keyword)

class myerror(Exception):
    def __int__(self,msg):
        self.msg=msg

def demo(a,b):
    if b!=0:
        return a/b
    else:
        raise myerror('check value of b')
demo(4,0)
# Out:
# ---------------------------------------------------------------------------
# myerror                                   Traceback (most recent call last)
# Cell In[4], line 12
#      10     else:
#      11         raise myerror('check value of b')
# ---> 12 demo(4,0)
#
# Cell In[4], line 11, in demo(a, b)
#       9     return a/b
#      10 else:
# ---> 11     raise myerror('check value of b')
#
# myerror: check value of b
