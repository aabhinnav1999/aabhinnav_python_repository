# %%
from abc import ABC,abstractmethod

class sample(ABC):
    pass

    @abstractmethod
    def display(self):
        return 'good evening'

class demo(sample):
    def display(self):
        return 'abstract class testing'
    pass

obj=demo()
