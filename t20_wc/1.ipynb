# %%
#1

import csv

fopen=open(r'D:\Python\t20_wc\Book1.csv','r')
fread=csv.DictReader(fopen)

l=[]

for i in fread:
    print(i)
    l+=[i]

print(l)
# Out:
# {'Year': '2007', 'Winners': 'India', 'Score': '157/5 (20 overs)', 'Runners_up': 'Pakistan', 'Score_r': '152 all out (19.4 overs)', 'Host(s)': 'South Africa', 'Winning Captain': 'MS Dhoni'}
# {'Year': '2009', 'Winners': 'Pakistan', 'Score': '139/2 (18.4 overs)', 'Runners_up': 'Sri Lanka', 'Score_r': '138/6 (20 overs)', 'Host(s)': 'England', 'Winning Captain': 'Younis Khan'}
# {'Year': '2010', 'Winners': 'England', 'Score': '148/3 (17 overs)', 'Runners_up': 'Australia', 'Score_r': '147/6 (20 overs)', 'Host(s)': 'West Indies', 'Winning Captain': 'Paul Collingwood'}
# {'Year': '2012', 'Winners': 'West Indies', 'Score': '137/6 (20 overs)', 'Runners_up': 'Sri Lanka', 'Score_r': '101 all out (18.4 overs)', 'Host(s)': 'Sri Lanka', 'Winning Captain': 'Daren Sammy'}
# {'Year': '2014', 'Winners': 'Sri Lanka', 'Score': '134/4 (17.5 overs)', 'Runners_up': 'India', 'Score_r': '130/4 (20 overs)', 'Host(s)': 'Bangladesh', 'Winning Captain': 'Lasith Malinga'}
# ...
