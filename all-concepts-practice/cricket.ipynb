# %%
#1

import csv

fo=open(r"C:\Users\abhin\Desktop\worldcup100s.csv",'r')
fr=csv.reader(fo)

a=0
for i in fr:
    print(i)
    a=a+1
    if a==10:
        break
# Out:
# ['No.', 'Player', 'Runs', 'Balls', '4s', '6s', 'S/R', 'Team', 'Opposition', 'Venue', 'Date', 'Result']
# ['1', 'Dennis Amiss', '137?', '147', '18', '0', '93.19', 'ÿEngland', 'ÿIndia', "Lord's,ÿLondon", '07-Jun-75', 'Won']
# ['2', 'Glenn Turner', '171*?', '201', '16', '2', '85.07', 'ÿNew Zealand', 'ÿEast Africa', 'Edgbaston Cricket Ground,ÿBirmingham', '07-Jun-75', 'Won']
# ['3', 'Keith Fletcher', '131', '147', '13', '0', '89.11', 'ÿEngland', 'ÿNew Zealand', 'Trent Bridge,ÿNottingham', '11-Jun-75', 'Won']
# ['4', 'Alan Turner', '101', '113', '9', '1', '89.38', 'ÿAustralia', 'ÿSri Lanka', 'The Oval,ÿLondon', '11-Jun-75', 'Won']
# ['5', 'Glenn Turner', '114*', '177', '13', '0', '64.4', 'ÿNew Zealand', 'ÿIndia', 'Old Trafford Cricket Ground,ÿManchester', '14-Jun-75', 'Won']
# ['6', 'Clive Lloyd', '102?', '85', '12', '2', '120', 'ÿWest Indies', 'ÿAustralia', "Lord's,ÿLondon", '21-Jun-75', 'Won']
# ...

# %%
#2

import csv

fo=open(r"D:\Python\all-concepts-practice\worldcup100s.csv",'r')
fr=csv.reader(fo)

a=0
for i in fr:
    if i[0]!='No.':
        if i[2].endswith('?')==True:
            print(i)
    # a=a+1
    # if a==10:
    #     break

# %%
#3

import csv
res=[]
fo=open(r"D:\Python\all-concepts-practice\worldcup100s.csv",'r')
fr=csv.reader(fo)
for i in fr:
    res+=[i]
fo.close()

#team
for i in res:
        if  not('a'<=i[-5][0]<='z') and not('A'<=i[-5][0]<='Z'):
            i[-5]=i[-5][3:]
            # print(i)
        else:
            pass

#runs
for i in res:
    if i[2].endswith('?')==True:
        # print(i[2][0:-1:1])
        i[2]=i[2][0:-1:1]

#opposition
for i in res:
        if  not('a'<=i[-4][0]<='z') and not('A'<=i[-4][0]<='Z'):
            i[-4]=i[-4][3:]
            # print(i[-4][3:])
        else:
            pass

#venue     
st1=''
for i in res:
    for j in i[-3]:
        if ord(j)>122:
            pass
        else:
            st1+=j
    # print(st1)
    i[-3]=st1
    st1=''
    


def check():
    for i in res:
        print(i[-3])
# print(check())

fo=open('worldcup100s-final.csv','w',newline='')
fw=csv.writer(fo)
fw.writerows(res)
fo.close()

# %%
#4 filtered worldcup matches csv

import csv
fo=open(r'D:\Python\all-concepts-practice\worldcup-matches-1-csv.csv','r')
fr=csv.reader(fo)
m=[]

for i in fr:
    m+=[i]

test1=''
f1=[]
a=0
for j in m:
    # print(j)
    a+=1
    for k in j[0]:
        if ('0'<=k<='9') or ('a'<=k<='z') or ('A'<=k<='Z'):
            test1+=k
    j[0]=test1
    # f1+=[test1]
    # print(f1[-1])
    test1=''
    
    # if a==3:
    #     break


for i in m:
    # print(i[1])
    if i[1].startswith('Mon')==True:
        i[1]=i[1][6:]+', Monday'
    elif i[1].startswith('Tue')==True:
        i[1]=i[1][6:]+', Tuesday'
    elif i[1].startswith('Wed')==True:
        i[1]=i[1][6:]+', Wednesday'
    elif i[1].startswith('Thur')==True:
        i[1]=i[1][6:]+', Thursday'
    elif i[1].startswith('Fri')==True:
        i[1]=i[1][6:]+', Friday'
    elif i[1].startswith('Sat')==True:
        i[1]=i[1][6:]+', Saturday'
    elif i[1].startswith('Sun')==True:
        i[1]=i[1][6:]+', Sunday'

for i in m:
    # print(i[1])
    if i[1].startswith('O')==True or i[1].startswith('N')==True or i[1].startswith('D')==True:
        pass
    else:
        i[1]=i[1][1:]
        
test2=''
for i in m:
    # print(i[0])
    if i[0]!='Matches':
        for j in i[0]:
            if 'A'<=j<='Z':
                test2+=j
            elif j=='v':
                test2+=' v'
            elif j=='s':
                test2+='s '
        i[0]=test2
        test2=''

fo99=open('worldcup-matches-1-final.csv','w',newline='')
fw99=csv.writer(fo99)
fw99.writerows(m)
fo99.close()

# %%
#5 read and modify

import csv

fo=open(r'D:\Python\all-concepts-practice\worldcup-matches-1-final.csv','r')
fr=csv.reader(fo)

res=[i for i in fr]

for i in res:
    i[0],i[1],i[3]=i[0].upper(),i[1].upper(),i[3].upper()

fo=open(r'D:\Python\all-concepts-practice\worldcup-matches-1-final.csv','w',newline='')
fr=csv.writer(fo)
fr.writerows(res)
fo.close()

# %%
#analysing data

with open('worldcup100s-final.csv','r') as fo:
    fr=csv.reader(fo)

    test=[]
    for i in fr:
        if i[2]!='Runs':
            if i[2].endswith('*'):
                test+=[int(i[2][0:-1])]
            else:
                test+=[int(i[2])]

    # test.sort()
    test2=min(test)

    
fo=open('worldcup100s-final.csv','r')
fr=csv.reader(fo)

for i in fr:
    if i[2]=='Runs':
        print(i)
    if i[-1]=='Tied':
        print(i)

# %%
#6 lowercase to uppercase

import csv

fo=open(r'D:\Python\all-concepts-practice\worldcup100s-final.csv','r')
fr=csv.reader(fo)

l=[]
for i in fr:
    l+=[i]

for i in range(0,len(l)):
    for j in range(0,len(l[i])):
        # print(l[i][j].upper())
        l[i][j]=l[i][j].upper()
    
        
fo=open(r'D:\Python\all-concepts-practice\worldcup100s-final.csv','w',newline='')
fr=csv.writer(fo)  

fr.writerows(l)
fo.close()

# %%
#7 changing date format 

import csv
fo=open(r'D:\Python\all-concepts-practice\worldcup100s-final.csv','r')
fr=csv.reader(fo)


l=[]
for i in fr:
    l+=[i]

for i in l:
    res=i[-2].split('-')[::-1]
    i[-2]='-'.join(res)

for i in l:
    if i[-2][0:2]=='75':
        i[-2]='19'+i[-2]
    elif i[-2][0:2]=='79':
        i[-2]='19'+i[-2]
    elif i[-2][0:2]=='83':
        i[-2]='19'+i[-2]
    elif i[-2][0:2]=='87':
        i[-2]='19'+i[-2]
    elif i[-2][0:2]=='92':
        i[-2]='19'+i[-2]
    elif i[-2][0:2]=='96':
        i[-2]='19'+i[-2]
    elif i[-2][0:2]=='99':
        i[-2]='19'+i[-2]
    elif i[-2][0:2]=='03':
        i[-2]='20'+i[-2]
    elif i[-2][0:2]=='07':
        i[-2]='20'+i[-2]
    elif i[-2][0:2]=='11':
        i[-2]='20'+i[-2]
    elif i[-2][0:2]=='15':
        i[-2]='20'+i[-2]
    elif i[-2][0:2]=='19':
        i[-2]='20'+i[-2]
    elif i[-2][0:2]=='23':
        i[-2]='20'+i[-2]
    

for i in l:
    if i[-2][5:8]=='JAN':
        i[-2]=i[-2][0:5]+'01'+i[-2][8:]
    elif i[-2][5:8]=='FEB':
        i[-2]=i[-2][0:5]+'02'+i[-2][8:]
    elif i[-2][5:8]=='MAR':
        i[-2]=i[-2][0:5]+'03'+i[-2][8:]
    elif i[-2][5:8]=='APR':
        i[-2]=i[-2][0:5]+'04'+i[-2][8:]
    elif i[-2][5:8]=='MAY':
        i[-2]=i[-2][0:5]+'05'+i[-2][8:]
    elif i[-2][5:8]=='JUN':
        i[-2]=i[-2][0:5]+'06'+i[-2][8:]
    elif i[-2][5:8]=='JUL':
        i[-2]=i[-2][0:5]+'07'+i[-2][8:]
    elif i[-2][5:8]=='AUG':
        i[-2]=i[-2][0:5]+'08'+i[-2][8:]
    elif i[-2][5:8]=='SEP':
        i[-2]=i[-2][0:5]+'09'+i[-2][8:]
    elif i[-2][5:8]=='OCT':
        i[-2]=i[-2][0:5]+'10'+i[-2][8:]
    elif i[-2][5:8]=='NOV':
        i[-2]=i[-2][0:5]+'11'+i[-2][8:]
    elif i[-2][5:8]=='DEC':
        i[-2]=i[-2][0:5]+'12'+i[-2][8:]

fo=open('worldcup100s-changed-date.csv','w',newline='')
fw=csv.writer(fo)
fw.writerows(l)
fo.close()

# %%
#8 creating table in mysql

import pymysql

db=pymysql.connect(host='127.0.0.1',port=3306,user='root',password='root',database='aabhinnav')
cus=db.cursor()

cus.execute("create table wc(id int primary key,name varchar(50),runs varchar(4),balls int,fours int,sixes int,strike_rate varchar(10),team varchar(25),opposition varchar(25),venue varchar(100),date date,result varchar(4))")
db.commit()

# %%
#9 inserting data into mysql from csvfile

import csv,pymysql

fo=open(r'./worldcup100s-final-changed-date.csv','r')
fr=csv.reader(fo)

for i in fr:
    if i[-1]!='RESULT':
        db=pymysql.connect(host='127.0.0.1',port=3306,user='root',password='root',database='aabhinnav')
        cus=db.cursor()
        cus.execute("insert into wc values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",i)
        db.commit()

# %%
#10 virat kohli 100s

import csv

fo=open(r'D:\Python\all-concepts-practice\kohli100s.csv','r')
fr=csv.reader(fo)

#adding to list
z=[]
for i in fr:
    z+=[i]

#modifying date
res=''
for k in z:
    if k[-2]!='Date':
        k[-2]=k[-2][0:-2]+'20'+k[-2].split('-')[-1]

#lowercase to uppercase
for i in range(0,len(z)):
    for j in range(0,len(z[i])):
        # print(z[i][j].upper())
        z[i][j]=z[i][j].upper()

#changing date format
for i in z:
    if i[-2][3:6]=='JAN':
        i[-2]=i[-2][0:3]+'01'+i[-2][6:]
    elif i[-2][3:6]=='FEB':
        i[-2]=i[-2][0:3]+'02'+i[-2][6:]
    elif i[-2][3:6]=='MAR':
        i[-2]=i[-2][0:3]+'03'+i[-2][6:]
    elif i[-2][3:6]=='APR':
        i[-2]=i[-2][0:3]+'04'+i[-2][6:]
    elif i[-2][3:6]=='MAY':
        i[-2]=i[-2][0:3]+'05'+i[-2][6:]
    elif i[-2][3:6]=='JUN':
        i[-2]=i[-2][0:3]+'06'+i[-2][6:]
    elif i[-2][3:6]=='JUL':
        i[-2]=i[-2][0:3]+'07'+i[-2][6:]
    elif i[-2][3:6]=='AUG':
        i[-2]=i[-2][0:3]+'08'+i[-2][6:]
    elif i[-2][3:6]=='SEP':
        i[-2]=i[-2][0:3]+'09'+i[-2][6:]
    elif i[-2][3:6]=='OCT':
        i[-2]=i[-2][0:3]+'10'+i[-2][6:]
    elif i[-2][3:6]=='NOV':
        i[-2]=i[-2][0:3]+'11'+i[-2][6:]
    elif i[-2][3:6]=='DEC':
        i[-2]=i[-2][0:3]+'12'+i[-2][6:]

#sorting by date format
z1=[]
for i in z:
    if i[-2]!='DATE':
        z1+=[i[-2].split('-')[::-1]]   
z1.sort()
for i in range(0,len(z1)):
    z1[i][0],z1[i][-1]=z1[i][-1],z1[i][0]
    # print(z1[i])
# z1=['DATE']+z1

#adding modified data to new list
z2=[]
for i in range(0,len(z1)):
    for j in z:
        if j[-2].split('-')==z1[i]:
            z2+=[j]

z3=[]
for i in z2:
    if i not in z3:
        z3+=[i]
res=1
z3=[z[0]]+z3
for i in z3:
    if i[0]!='NO.':
        i[0]=res
        res+=1

z3[0][0]='NO'
for i in z3:
    i[3:3]=[i[-1]]
    del i[-1]
    # print(i)

fo=open(r'D:\Python\all-concepts-practice\kohli100s-final.csv','w',newline='')
fw=csv.writer(fo)
fw.writerows(z3)
fo.close()

# %%
#11 fectching data

import csv

def func1():
    fo=open(r'D:\Python\all-concepts-practice\kohli100s-final.csv','r')
    fr=csv.reader(fo)
    a=0
    for i in fr:
        if i[3]=='odi'.upper():
            if i[1].endswith('*')==True:
                if int(i[1][0:-1])>150:
                    a+=1
                    print(i)
            else:
                if int(i[1])>150:
                    a+=1
                    print(i)
    print('records found -----',a)

def func2():
    fo=open(r'D:\Python\all-concepts-practice\kohli100s-final.csv','r')
    fr=csv.reader(fo)
    a=0
    for i in fr:
        if i[-1].endswith('2023')==True:
            a+=1
            print(i)
    print('records found -----',a)

# %%
#12 adding new column

import csv

fo=open(r'D:\Python\all-concepts-practice\kohli100s-final.csv','r')
fr=csv.reader(fo)

l=[]
for i in fr:
    l+=[i]

for i in l:
    if i[-1]=='date'.upper():
        i[2:2]=['o/no'.upper()]
    else:
        i[2:2]=['demo'.upper()]

for i in l:
    if i[0]!='NO':
        if i[1].endswith('*')==True:
            i[1]=i[1][0:-1]
            i[2]='not out'.upper()
        else:
            i[2]='out'.upper()

fo=open(r'D:\Python\all-concepts-practice\kohli100s-final.csv','w',newline='')
fr=csv.writer(fo)
fr.writerows(l)
fo.close()

# %%
#13 practice

import csv

fo=open(r"C:\Users\abhin\OneDrive\Desktop\Book1.csv",'r')
fr=csv.reader(fo)

l=[]
for i in fr:
    l+=[i]

for i in l:
    if  not('a'<=i[-5][0]<='z') and not('A'<=i[-5][0]<='Z'):
        i[-5]=i[-5][3:]
    else:
        pass

for i in l:
    if  not('a'<=i[8][0]<='z') and not('A'<=i[8][0]<='Z'):
        i[8]=i[8][3:]
    else:
        pass

for i in range(0,len(l)):
    for j in range(0,len(l[i])):
        l[i][j]=l[i][j].upper()
    
        

for i in l:
    i[-2]='20'+i[-2].split('-')[::-1][0]+'-11'+'-'+i[-2].split('-')[::-1][-1]

fo=open(r'C:\Users\abhin\OneDrive\Desktop\Book1.csv','w',newline='')
fw=csv.writer(fo)
fw.writerows(l)
fo.close()

# %%
#14 practice

import csv,pymysql

fo=open(r'C:\Users\abhin\OneDrive\Desktop\Book1.csv','r')
fr=csv.reader(fo)

for i in fr:
    if i[-1]!='RESULT':
        db=pymysql.connect(host='database-1.cxbftnytvoi3.us-east-1.rds.amazonaws.com',port=3306,user='adminroot',password='adminroot',database='mydb')
        cus=db.cursor()
        cus.execute("insert into hundreds values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",i)
        db.commit()

# %%
#15 analysing

import csv

fo=open(r'D:\Python\all-concepts-practice\worldcup100s-final-changed-date.csv','r')
fr=csv.reader(fo)

a=0
for i in fr:
    if i[7]=='INDIA':
        if i[2].endswith('*')==True:
            if int(i[2][0:-1])>150:
                a+=1
                print(i)
        elif int(i[2])>150:
            a+=1
            print(i)
print('records --------',a)
# Out:
# ['15', 'KAPIL DEV', '175*', '138', '16', '6', '126.81', 'INDIA', 'ZIMBABWE', 'NEVILL GROUND,ROYAL TUNBRIDGE WELLS', '1983-06-18', 'WON']
# ['54', 'SOURAV GANGULY', '183', '158', '17', '7', '115.82', 'INDIA', 'SRI LANKA', 'COUNTY GROUND,TAUNTON', '1999-05-26', 'WON']
# ['71', 'SACHIN TENDULKAR', '152', '151', '18', '0', '100.66', 'INDIA', 'NAMIBIA', 'CITY OVAL,PIETERMARITZBURG', '2003-02-23', 'WON']
# ['104', 'VIRENDER SEHWAG', '175', '140', '14', '5', '125', 'INDIA', 'BANGLADESH', 'SHER-E-BANGLA CRICKET STADIUM,DHAKA', '2011-02-19', 'WON']
# records -------- 4

# %%
#16

import pymysql

db=pymysql.connect(host='127.0.0.1',port=3306,user='root',password='root',database='aabhinnav')
cus=db.cursor()
cus.execute("select * from wc")
res=cus.fetchall()


a=0
for i in res:
    print(i[-2])
    a+=1

print('records =====',a)

# start=1
# while start<=a:
#     db=pymysql.connect(host='127.0.0.1',port=3306,user='root',password='root',database='aabhinnav')
#     cus=db.cursor()
#     cus.execute("update wc set time(date)=time(current_timestamp()) where id=%s",start)
#     db.commit()
