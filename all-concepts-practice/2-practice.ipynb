# %%
#1 create csv file

import csv

fo=open('2-practice.csv','w',newline='')
fw=csv.writer(fo)

fw.writerow(['slno','name','job','employee_id'])
fo.close()

# %%
#2

fo=open(r'D:\Python\all-concepts-practice\2-practice.csv','r')
fr=csv.reader(fo)

res=[]
for i in fr:
    if i[0]!='slno':
        res+=[i[0]]

def demo():
    if len(res)!=0:
        return res[-1]
    else:
        return 0

fo2=open(r'D:\Python\all-concepts-practice\2-practice.csv','a',newline='')
fw=csv.writer(fo2)
one=int(demo())+1
fw.writerow([])
fo.close()

# %%
#3 insert multiple records into csv file

fo=open(r'D:\Python\all-concepts-practice\1-csv-file.csv','r')
fr=csv.reader(fo)


# fopen=open(r'D:\Python\all-concepts-practice\2-practice.csv','r')
# fread=csv.reader(fopen)

# res=[]
# for i in fread:
#     if i[0]!='slno':
#         res+=[i[0]]

for i in fr:
    if i[0]!='employee_id':

        def demo():
            fopen=open(r'D:\Python\all-concepts-practice\2-practice.csv','r')
            fread=csv.reader(fopen)
            res=[]

            for i in fread:
                if i[0]!='slno':
                    res+=[i[0]]
                    
            if len(res)!=0:
                return res[-1]
            else:
                return 0
            
        fo2=open(r'D:\Python\all-concepts-practice\2-practice.csv','a',newline='')
        fw=csv.writer(fo2)
        one=int(demo())+1
        fw.writerow([one,i[1],i[3],i[0]])


fo.close()
fo2.close()

# %%
#4 insert single record into csv file

import csv

def demo():
            fopen=open(r'D:\Python\all-concepts-practice\2-practice.csv','r')
            fread=csv.reader(fopen)
            res=[]

            for i in fread:
                if i[0]!='slno':
                    res+=[i[0]]
                    
            if len(res)!=0:
                return res[-1]
            else:
                return 0


f99=open(r'D:\Python\all-concepts-practice\2-practice.csv','a',newline='')
fw99=csv.writer(f99)
fw99.writerow([int(demo())+1,'king','president','11311'])
f99.close()

# %%
#5 string replace function

import csv

fo=open(r"D:\Python\all-concepts-practice\3-csv-sample2.csv",'r')
fr=csv.reader(fo)

for i in fr:
    print(i[0].replace(i[0],i[0].upper()),i[1].replace(i[1],i[1].upper()),i[2].replace(i[2],i[2].upper()),i[3].replace(i[3],i[3].upper()))
# Out:
# EMPID NAME SAL LOC
# 1010 SCOTT 1900 CALIFORNIA
# 1020 KING 2500 DELHI
# 1030 JOHN 2500 LONDON
# 1040 MILLER 1500 TOKOYO
