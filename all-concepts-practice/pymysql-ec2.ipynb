# %%
#creating table

import pymysql

db=pymysql.connect(host='aabhinnav.cxbftnytvoi3.us-east-1.rds.amazonaws.com',port=3306,user='admin',password='adminadmin',database='pyspiders')
cus=db.cursor()

cus.execute("create table teacher(id int(4),tname varchar(20))")
db.commit()

# %%
#inserting records

import pymysql

db=pymysql.connect(host='aabhinnav.cxbftnytvoi3.us-east-1.rds.amazonaws.com',port=3306,user='admin',password='adminadmin',database='pyspiders')
cus=db.cursor()

cus.execute("insert into teacher values(19,'aabhinnav')")
db.commit()
