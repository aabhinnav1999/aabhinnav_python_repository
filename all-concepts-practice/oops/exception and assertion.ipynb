# %%
#1

a=0
b=1000

try:
    for i in range(a,b):
        print(i)
except:
    print('this is error')

# %%
#2

class PYSERROR(Exception):
    def __init__(self,msg) -> None:
        pass
        

print('start')

a=10
if a==10:
    raise PYSERROR('my custom error')

print('stop')
# Out:
# start
# ---------------------------------------------------------------------------
# PYSERROR                                  Traceback (most recent call last)
# Cell In[17], line 12
#      10 a=10
#      11 if a==10:
# ---> 12     raise PYSERROR('my custom error')
#      14 print('stop')
#
# PYSERROR: my custom error

# %%
#3 assertion

a=10
b=14

def sample(a,b):
    return int(a-b)

assert sample(a,b) ==4,'answer must be +4'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[23], line 9
#       6 def sample(a,b):
#       7     return int(a-b)
# ----> 9 assert sample(a,b) ==4,'answer must be +4'
#
# AssertionError: answer must be +4
