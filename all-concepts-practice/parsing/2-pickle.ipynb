# %%
#1 python to pickle (pickling)
#dumps

import pickle

d={'date':'19-03-2024','location':'telangana'}
print((d),type(d))

res=pickle.dumps(d)
print(res,type(res))
# Out:
# {'date': '19-03-2024', 'location': 'telangana'} <class 'dict'>
# b'\x80\x04\x950\x00\x00\x00\x00\x00\x00\x00}\x94(\x8c\x04date\x94\x8c\n19-03-2024\x94\x8c\x08location\x94\x8c\ttelangana\x94u.' <class 'bytes'>

# %%
#2 store in pkl file
#dump

import pickle

d={'name':'abhinav','age':24,'dept':'ece','dob':'19-04-1999'}
fo=open('pickle-1.pkl','wb')
pickle.dump(d,fo)
fo.close()

# %%
#3 loads

import pickle

fo=open('pickle-1.pkl','rb')
r=fo.read()
print(pickle.loads(r))
# Out:
# {'name': 'abhinav', 'age': 24, 'dept': 'ece', 'dob': '19-04-1999'}

# %%
#4 load

import pickle

fo=open('pickle-1.pkl','rb')
print(pickle.load(fo))
# Out:
# {'name': 'abhinav', 'age': 24, 'dept': 'ece', 'dob': '19-04-1999'}

# %%
#5 csv to pkl

import pickle,csv

fo=open(r'D:\Python\all-concepts-practice\8-1.csv','r')
fr=csv.DictReader(fo)

d={}
a=0

for i in fr:
    a+=1
    # print(i)
    d[a]=i

# print(d)
    
fopen=open('pickle-2.pkl','wb')
pickle.dump(d,fopen)
fopen.close()

# %%
#6 reading  from pkl file

import pickle

fopen=open('pickle-2.pkl','rb')
r=pickle.load(fopen)

print(r)

for i in r:
    print(i)
# Out:
# {1: {'name': 'abhinav', 'age': '24', 'department': 'ece'}, 2: {'name': 'anudeep', 'age': '20', 'department': 'ece'}, 3: {'name': 'ram', 'age': '25', 'department': 'cse'}, 4: {'name': 'pavan', 'age': '30', 'department': 'civil'}}
# 1
# 2
# 3
# 4
