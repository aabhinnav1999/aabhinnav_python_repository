# %%
#1 python to json (serialization or dumping)
#dumps

import json

d={'name':'aabhinnav','dept':'ece'}
# d='hello world'
print(d)
print(type(d))

res=json.dumps(d)
print(res)
print(type(res))
# Out:
# {'name': 'aabhinnav', 'dept': 'ece'}
# <class 'dict'>
# {"name": "aabhinnav", "dept": "ece"}
# <class 'str'>

# %%
#2 json to python (deserialization or loading)
#loads

print(res,type(res))
res=json.loads(res)
print(res,type(res))
# Out:
# {"name": "aabhinnav", "dept": "ece"} <class 'str'>
# {'name': 'aabhinnav', 'dept': 'ece'} <class 'dict'>

# %%
#3 dump

import json

d={'name':'abhinav','age':24,'dept':'ece'}
fo=open('json-1.txt','w')
json.dump(d,fo)
fo.close()

# %%
#4 load

import json

fr=open('json-1.txt','r')
res=json.load(fr)
print(res,type(res))
fr.close()
# Out:
# {'name': 'abhinav', 'age': 24, 'dept': 'ece'} <class 'dict'>

# %%
#5 write to json file

import json

d={'1':{'name':'abhinav','age':24},
   '2':{'name':'anudeep','age':20} }

fo=open('json-1.json','w')
json.dump(d,fo,indent=4)

fo.close()

# %%
#6 reading from json file

import json

fo=open(r'D:\Python\all-concepts-practice\parsing\json-1.json','r')

res=json.load(fo)

print(res)

for i in res:
    print(i,res[i])
# Out:
# {'1': {'name': 'abhinav', 'age': 24}, '2': {'name': 'anudeep', 'age': 20}}
# 1 {'name': 'abhinav', 'age': 24}
# 2 {'name': 'anudeep', 'age': 20}

# %%
#7 fetching from csv and storing in json file

import json,csv

f1=open(r"D:\Python\all-concepts-practice\2-practice.csv",'r')
fr1=csv.DictReader(f1)

d={}
for i in fr1:
    # print(i)
    d[i['slno']]=i

# print(d)
    
f2=open('json-2.json','w')
json.dump(d,f2,indent=4)
f2.close()
