# %%
#1

def outer(func):
    def inner(*args,**kwargs):
        print('haii')
        # print(func)
        print(func(*args,**kwargs))
        print('bye')
    return inner

@outer
def sample(a,b):
    return a+b
sample(10,20)
# Out:
# haii
# 30
# bye
