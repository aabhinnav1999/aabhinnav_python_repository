# %%
#1 read

fo=open(r'D:\Python\all-concepts-practice\model-file.txt','r')

def uread():
    fr=fo.read()
    print(fr)

frl=fo.readlines()
print(frl)

for i in frl:
    print(i)

# %%
#2 write

l=['first line\n','second line\n','third line\n','fourth line\n','last line']

with open('sample1.txt','w+') as fo:
    for i in l:
        fo.write(i)
    fo.seek(0)
    fr=fo.read()
print(fr)

# for i in l:
#     fo=open('sample1.txt','w')
#     fo.write(i)
#     fo.close()
